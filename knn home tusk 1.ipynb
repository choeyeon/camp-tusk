# %%
import pandas as pd 
import numpy as np 
np.random.seed = 2021
from sklearn.datasets import load_iris
iris = load_iris()
print ('data contains:',iris.keys())
X, y, labels, feature_names  = iris.data, iris.target, iris.target_names, iris['feature_names']
df_iris= pd.DataFrame(X, columns= feature_names) 
df_iris['label'] =  y
features_dict = {k:v for k,v in  enumerate(labels)}
df_iris['label_names'] = df_iris.label.apply(lambda x: features_dict[x])
df_iris
# Out:
# data contains: dict_keys(['data', 'target', 'target_names', 'DESCR', 'feature_names', 'filename'])
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# 5                  5.4               3.9                1.7               0.4
# 6                  4.6               3.4                1.4               0.3
# 7                  5.0               3.4                1.5               0.2
# 8                  4.4               2.9                1.4               0.2
# 9                  4.9               3.1                1.5               0.1
# 10                 5.4               3.7                1.5               0.2
# 11                 4.8               3.4                1.6               0.2
# 12                 4.8               3.0                1.4               0.1
# 13                 4.3               3.0                1.1               0.1
# 14                 5.8               4.0                1.2               0.2
# 15                 5.7               4.4                1.5               0.4
# 16                 5.4               3.9                1.3               0.4
# 17                 5.1               3.5                1.4               0.3
# 18                 5.7               3.8                1.7               0.3
# 19                 5.1               3.8                1.5               0.3
# 20                 5.4               3.4                1.7               0.2
# 21                 5.1               3.7                1.5               0.4
# 22                 4.6               3.6                1.0               0.2
# 23                 5.1               3.3                1.7               0.5
# 24                 4.8               3.4                1.9               0.2
# 25                 5.0               3.0                1.6               0.2
# 26                 5.0               3.4                1.6               0.4
# 27                 5.2               3.5                1.5               0.2
# 28                 5.2               3.4                1.4               0.2
# 29                 4.7               3.2                1.6               0.2
# ..                 ...               ...                ...               ...
# 120                6.9               3.2                5.7               2.3
# 121                5.6               2.8                4.9               2.0
# 122                7.7               2.8                6.7               2.0
# 123                6.3               2.7                4.9               1.8
# 124                6.7               3.3                5.7               2.1
# 125                7.2               3.2                6.0               1.8
# 126                6.2               2.8                4.8               1.8
# 127                6.1               3.0                4.9               1.8
# 128                6.4               2.8                5.6               2.1
# 129                7.2               3.0                5.8               1.6
# 130                7.4               2.8                6.1               1.9
# 131                7.9               3.8                6.4               2.0
# 132                6.4               2.8                5.6               2.2
# 133                6.3               2.8                5.1               1.5
# 134                6.1               2.6                5.6               1.4
# 135                7.7               3.0                6.1               2.3
# 136                6.3               3.4                5.6               2.4
# 137                6.4               3.1                5.5               1.8
# 138                6.0               3.0                4.8               1.8
# 139                6.9               3.1                5.4               2.1
# 140                6.7               3.1                5.6               2.4
# 141                6.9               3.1                5.1               2.3
# 142                5.8               2.7                5.1               1.9
# 143                6.8               3.2                5.9               2.3
# 144                6.7               3.3                5.7               2.5
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      label label_names
# 0        0      setosa
# 1        0      setosa
# 2        0      setosa
# 3        0      setosa
# 4        0      setosa
# 5        0      setosa
# 6        0      setosa
# 7        0      setosa
# 8        0      setosa
# 9        0      setosa
# 10       0      setosa
# 11       0      setosa
# 12       0      setosa
# 13       0      setosa
# 14       0      setosa
# 15       0      setosa
# 16       0      setosa
# 17       0      setosa
# 18       0      setosa
# 19       0      setosa
# 20       0      setosa
# 21       0      setosa
# 22       0      setosa
# 23       0      setosa
# 24       0      setosa
# 25       0      setosa
# 26       0      setosa
# 27       0      setosa
# 28       0      setosa
# 29       0      setosa
# ..     ...         ...
# 120      2   virginica
# 121      2   virginica
# 122      2   virginica
# 123      2   virginica
# 124      2   virginica
# 125      2   virginica
# 126      2   virginica
# 127      2   virginica
# 128      2   virginica
# 129      2   virginica
# 130      2   virginica
# 131      2   virginica
# 132      2   virginica
# 133      2   virginica
# 134      2   virginica
# 135      2   virginica
# 136      2   virginica
# 137      2   virginica
# 138      2   virginica
# 139      2   virginica
# 140      2   virginica
# 141      2   virginica
# 142      2   virginica
# 143      2   virginica
# 144      2   virginica
# 145      2   virginica
# 146      2   virginica
# 147      2   virginica
# 148      2   virginica
# 149      2   virginica
#
# [150 rows x 6 columns]

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(df_iris, test_size=0.3)

# %%
X_train = train[['sepal length (cm)','sepal width (cm)','petal length (cm)','petal width (cm)']]
y_train = train['label']
X_test = test[['sepal length (cm)','sepal width (cm)','petal length (cm)','petal width (cm)']]

y_test = test['label']


print ('X_train.shape=', X_train.shape)
print ('y_train.shape=', y_train.shape)
print ('X_test.shape=', X_test.shape)
print ('y_test.shape=', y_test.shape)
print ('X_train[0]=')
X_train.iloc[0]
# Out:
# X_train.shape= (105, 4)
# y_train.shape= (105,)
# X_test.shape= (45, 4)
# y_test.shape= (45,)
# X_train[0]=
# sepal length (cm)    6.7
# sepal width (cm)     3.1
# petal length (cm)    5.6
# petal width (cm)     2.4
# Name: 140, dtype: float64

# %%
flower_dict = dict(zip(df_iris['label'].unique(), df_iris['label_names'].unique()))
print (flower_dict)
# Out:
# {0: 'setosa', 1: 'versicolor', 2: 'virginica'}

# %%
from sklearn.preprocessing import StandardScaler
import numpy as np

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
#  [ 0.12638892 -0.1539913   0.81912815  0.86622652]
#  [ 0.59203229 -0.81847433  0.70836388  0.86622652]
#  [ 1.17408651 -0.59697999  0.65298174  0.34649061]
#  [-0.80489784  0.73198607 -1.17462871 -1.21271712]
#  [-0.4556653  -0.1539913   0.48683534  0.47642458]
#  [-0.10643277  2.94692949 -1.17462871 -0.95284917]
#  [-0.80489784  0.95348041 -1.23001084 -1.21271712]
#  [ 1.05767567  0.51049172  1.15142096  1.25602845]
#  [-0.4556653   1.83945778 -1.28539298 -0.95284917]
#  [-1.73618459 -0.1539913  -1.39615725 -1.3426511 ]
#  [-0.22284362 -1.26146302  0.15454253 -0.04331133]
#  [ 0.82485398 -0.1539913   1.20680309  1.38596242]
#  [-0.68848699 -0.81847433  0.15454253  0.34649061]
#  [ 1.52331904 -0.1539913   1.26218523  1.25602845]]

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
clf= KNeighborsClassifier(n_neighbors=5)
clf.fit(X_train_scaled, y_train)
print ('score train = {:.3f}'.format(clf.score(X_train_scaled,y_train)))
print ('score test = {:.3f}'.format(clf.score(X_test_scaled,y_test)))
# Out:
# score train = 0.971
# score test = 0.978

# %%
clf= KNeighborsClassifier(n_neighbors=4)
clf.fit(X_train_scaled, y_train)
print ('score train = {:.3f}'.format(clf.score(X_train_scaled,y_train)))
print ('score test = {:.3f}'.format(clf.score(X_test_scaled,y_test)))
# Out:
# score train = 0.962
# score test = 0.956

# %%
clf= KNeighborsClassifier(n_neighbors=10)
clf.fit(X_train_scaled, y_train)
print ('score train = {:.3f}'.format(clf.score(X_train_scaled,y_train)))
print ('score test = {:.3f}'.format(clf.score(X_test_scaled,y_test)))
# Out:
# score train = 0.952
# score test = 0.978

# %%
clf= KNeighborsClassifier(n_neighbors=9)
clf.fit(X_train_scaled, y_train)
print ('score train = {:.3f}'.format(clf.score(X_train_scaled,y_train)))
print ('score test = {:.3f}'.format(clf.score(X_test_scaled,y_test)))
# Out:
# score train = 0.943
# score test = 0.978

# %%
clf= KNeighborsClassifier(n_neighbors=11)
clf.fit(X_train_scaled, y_train)
print ('score train = {:.3f}'.format(clf.score(X_train_scaled,y_train)))
print ('score test = {:.3f}'.format(clf.score(X_test_scaled,y_test)))
# Out:
# score train = 0.943
# score test = 0.956

# %%
clf= KNeighborsClassifier(n_neighbors=7)
clf.fit(X_train_scaled, y_train)
print ('score train = {:.3f}'.format(clf.score(X_train_scaled,y_train)))
print ('score test = {:.3f}'.format(clf.score(X_test_scaled,y_test)))
# Out:
# score train = 0.952
# score test = 0.956

# %%
k_best = 10
score_best = 'score train = 0.952, score test = 0.978'
print ('The best k = {} , score = {}'.format(k_best,score_best ))
# Out:
# The best k = 10 , score = score train = 0.952, score test = 0.978
